# %% [markdown]
# # Result visualization
#
# Use this notebook to inspect heatmaps, overlays, and score distributions.

# %%
from pathlib import Path

list(Path('../outputs/heatmaps').glob('*.png'))[:5]
