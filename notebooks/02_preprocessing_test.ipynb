# %% [markdown]
# # Preprocessing test
#
# Use this notebook to compare resize, grayscale, blur, edge, and histogram settings.

# %%
from src.preprocessing import ImagePreprocessor

preprocessor = ImagePreprocessor(image_size=256)
preprocessor
