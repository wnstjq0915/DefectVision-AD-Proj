# %% [markdown]
# # Dataset exploration
#
# Use this notebook to inspect category counts, defect types, and masks.

# %%
from src.config import load_config
from src.datasets import build_dataset

config = load_config('../configs/model_autoencoder.yaml')
dataset = build_dataset(config, split='train')
len(dataset), dataset[0].keys()
